# %% [markdown]
# # Dataset CIFAR10

# %%
from keras.datasets import cifar10
import pandas as pd
import numpy as np

# %% [markdown]
# ### Carregando e Separando dataset

# %%
dataset = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 38s 0us/step

# %%
(x_train, y_train), (x_test, y_test) = dataset

# %% [markdown]
# ### Visualizando os dados

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
for i in range(9):
    # define subplot
    plt.subplot(330 + 1 + i)
    # plot raw pixel data
    plt.imshow(x_train[i])
# show the figure
plt.show()

# %% [markdown]
# ### Normalizando os dados

# %%
# Normalizando os dados
x_train = x_train.astype('f') / 255.0
x_test = x_test.astype('f') / 255.

# %%
# Ideal era utilizar o keras.utils.to_category()
# y_train = utils.to_category(y_train)

from sklearn.preprocessing import LabelBinarizer
lb = LabelBinarizer()
y_train = lb.fit_transform(y_train)
y_test = lb.transform(y_test)

# %% [markdown]
# ### Criando o Modelo

# %%
from keras.layers import Conv2D, MaxPooling2D, Dropout, BatchNormalization, Flatten, Dense
from keras.models import Sequential
import keras.backend as K

# %%
K.image_data_format()
# Out:
# 'channels_last'

# %%
input_Shape = (32, 32, 3)

model = Sequential()

model.add(Conv2D(32, (3,3), input_shape = input_Shape, activation = 'relu', kernel_initializer = 'he_uniform', padding = 'same'))
model.add(BatchNormalization(axis=-1))
model.add(Conv2D(32, (3,3), activation = 'relu', kernel_initializer = 'he_uniform', padding = 'same'))
model.add(BatchNormalization(axis=-1))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))

model.add(Conv2D(64, (3, 3), activation = 'relu', kernel_initializer = 'he_uniform', padding = 'same'))
model.add(BatchNormalization(axis=-1))
model.add(Conv2D(64, (3, 3), activation = 'relu', kernel_initializer = 'he_uniform', padding = 'same'))
model.add(BatchNormalization(axis=-1))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))

model.add(Conv2D(128, (3, 3), activation = 'relu', kernel_initializer = 'he_uniform', padding = 'same'))
model.add(BatchNormalization(axis=-1))
model.add(Conv2D(128, (3, 3), activation = 'relu', kernel_initializer = 'he_uniform', padding = 'same'))
model.add(BatchNormalization(axis=-1))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))

model.add(Flatten())
model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
model.add(BatchNormalization(axis=-1))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))

opt = 'sgd'

model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

# %% [markdown]
# ### Image Data Genarator

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
aug = ImageDataGenerator(rotation_range=20, zoom_range=0.15,
                         width_shift_range=0.2, height_shift_range=0.2, shear_range=0.15,
                         horizontal_flip=True, fill_mode="nearest")

# %%
dataset_train = aug.flow(x_train, y_train, batch_size=64)

# %%
steps = int(x_train.shape[0] / 64)

H = model.fit_generator(dataset_train, steps_per_epoch=steps, epochs=50, 
                        validation_data=(x_test, y_test), verbose=1)
# Out:
# Epoch 1/50
# 781/781 [==============================] - 497s 637ms/step - loss: 2.1509 - acc: 0.2878 - val_loss: 1.5134 - val_acc: 0.4479
# Epoch 2/50
# 781/781 [==============================] - 495s 634ms/step - loss: 1.7092 - acc: 0.3760 - val_loss: 1.4885 - val_acc: 0.4592
# Epoch 3/50
# 781/781 [==============================] - 491s 629ms/step - loss: 1.5979 - acc: 0.4119 - val_loss: 1.4497 - val_acc: 0.4676
# Epoch 4/50
# 781/781 [==============================] - 495s 634ms/step - loss: 1.5305 - acc: 0.4417 - val_loss: 1.3814 - val_acc: 0.4945
# Epoch 5/50
# 781/781 [==============================] - 492s 630ms/step - loss: 1.4711 - acc: 0.4635 - val_loss: 1.3498 - val_acc: 0.5114
# Epoch 6/50
# 781/781 [==============================] - 499s 640ms/step - loss: 1.4325 - acc: 0.4789 - val_loss: 1.3552 - val_acc: 0.5125
# Epoch 7/50
# 781/781 [==============================] - 494s 632ms/step - loss: 1.3885 - acc: 0.4993 - val_loss: 1.3615 - val_acc: 0.5126
# Epoch 8/50
# 781/781 [==============================] - 495s 633ms/step - loss: 1.3467 - acc: 0.5162 - val_loss: 1.5077 - val_acc: 0.4896
# Epoch 9/50
# 781/781 [==============================] - 492s 630ms/step - loss: 1.3261 - acc: 0.5265 - val_loss: 1.2648 - val_acc: 0.5426
# Epoch 10/50
# 781/781 [==============================] - 494s 633ms/step - loss: 1.2948 - acc: 0.5356 - val_loss: 1.4159 - val_acc: 0.5110
# Epoch 11/50
# 781/781 [==============================] - 493s 632ms/step - loss: 1.2664 - acc: 0.5463 - val_loss: 1.2272 - val_acc: 0.5465
# Epoch 12/50
# 781/781 [==============================] - 494s 632ms/step - loss: 1.2439 - acc: 0.5540 - val_loss: 1.3545 - val_acc: 0.5247
# Epoch 13/50
# 781/781 [==============================] - 491s 629ms/step - loss: 1.2333 - acc: 0.5605 - val_loss: 1.0927 - val_acc: 0.6009
# Epoch 14/50
# 781/781 [==============================] - 492s 629ms/step - loss: 1.2047 - acc: 0.5692 - val_loss: 1.3624 - val_acc: 0.5253
# Epoch 15/50
# 781/781 [==============================] - 493s 632ms/step - loss: 1.1872 - acc: 0.5782 - val_loss: 1.1111 - val_acc: 0.5986
# Epoch 16/50
# 781/781 [==============================] - 493s 631ms/step - loss: 1.1737 - acc: 0.5783 - val_loss: 1.1011 - val_acc: 0.5978
# Epoch 17/50
# 781/781 [==============================] - 491s 629ms/step - loss: 1.1535 - acc: 0.5870 - val_loss: 1.1760 - val_acc: 0.5764
# Epoch 18/50
# 781/781 [==============================] - 493s 631ms/step - loss: 1.1387 - acc: 0.5958 - val_loss: 1.2311 - val_acc: 0.5769
# Epoch 19/50
# 781/781 [==============================] - 494s 633ms/step - loss: 1.1264 - acc: 0.5990 - val_loss: 1.2915 - val_acc: 0.5484
# Epoch 20/50
# 781/781 [==============================] - 492s 630ms/step - loss: 1.1153 - acc: 0.6038 - val_loss: 1.0987 - val_acc: 0.6129
# Epoch 21/50
# 781/781 [==============================] - 493s 632ms/step - loss: 1.0984 - acc: 0.6138 - val_loss: 1.1298 - val_acc: 0.6088
# Epoch 22/50
# Epoch 41/50
# 781/781 [==============================] - 498s 637ms/step - loss: 0.9040 - acc: 0.6858 - val_loss: 0.8626 - val_acc: 0.7055
# Epoch 42/50
# 781/781 [==============================] - 496s 635ms/step - loss: 0.8953 - acc: 0.6886 - val_loss: 0.8738 - val_acc: 0.7006
# Epoch 43/50
# 781/781 [==============================] - 495s 634ms/step - loss: 0.9000 - acc: 0.6838 - val_loss: 0.8049 - val_acc: 0.7218
# Epoch 44/50
# 781/781 [==============================] - 498s 637ms/step - loss: 0.8849 - acc: 0.6912 - val_loss: 0.8328 - val_acc: 0.7139
# Epoch 45/50
# 781/781 [==============================] - 499s 639ms/step - loss: 0.8806 - acc: 0.6945 - val_loss: 0.8284 - val_acc: 0.7175
# Epoch 46/50
# 781/781 [==============================] - 499s 639ms/step - loss: 0.8724 - acc: 0.6953 - val_loss: 0.8987 - val_acc: 0.6947
# Epoch 47/50
# 781/781 [==============================] - 500s 640ms/step - loss: 0.8674 - acc: 0.6997 - val_loss: 0.8012 - val_acc: 0.7268
# Epoch 48/50
# 781/781 [==============================] - 498s 638ms/step - loss: 0.8625 - acc: 0.6995 - val_loss: 0.8235 - val_acc: 0.7240
# Epoch 49/50
# 781/781 [==============================] - 495s 634ms/step - loss: 0.8577 - acc: 0.7005 - val_loss: 0.8378 - val_acc: 0.7200
# Epoch 50/50
# 781/781 [==============================] - 497s 637ms/step - loss: 0.8497 - acc: 0.7037 - val_loss: 0.8558 - val_acc: 0.7197

# %%
plt.figure()
plt.plot(H.history['loss'], label='train_loss')
plt.plot(H.history['acc'], label='train_acc')
plt.plot(H.history['val_loss'], label='val_loss')
plt.plot(H.history['val_acc'], label='val_acc')
plt.title('Gráfico de validação')
plt.xlabel("Epochs")
plt.ylabel("loss/accuracy")
plt.legend()
plt.show()

# %%
scores = model.evaluate(x_test, y_test)
print("loss: ", scores[0])
print("acc: ", scores[1])
# Out:
# 10000/10000 [==============================] - 75s 8ms/step
# loss:  0.8558133193016052
# acc:  0.7197

# %%
preds = model.predict_classes(x_test)

# %%
preds = lb.fit_transform(preds)

# %%
from sklearn import metrics
# Out:
# /home/matheusjerico/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
print(metrics.classification_report(y_test, preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.78      0.79      1000
#            1       0.85      0.90      0.87      1000
#            2       0.85      0.41      0.56      1000
#            3       0.70      0.38      0.49      1000
#            4       0.74      0.60      0.66      1000
#            5       0.75      0.57      0.65      1000
#            6       0.47      0.96      0.63      1000
#            7       0.72      0.86      0.78      1000
#            8       0.90      0.83      0.86      1000
#            9       0.75      0.92      0.83      1000
#
#    micro avg       0.72      0.72      0.72     10000
#    macro avg       0.75      0.72      0.71     10000
# weighted avg       0.75      0.72      0.71     10000
#  samples avg       0.72      0.72      0.72     10000
